# %% [markdown]
# # 1. Problem Framing

# %% [markdown]
# Poor mental health days is the target variable.

# %% [markdown]
# # 2. Data Exploration

# %% [markdown]
# First the relevant libraries must be imported.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import missingno
import itertools
warnings.filterwarnings("ignore")

# %% [markdown]
# The data is then read from a .csv file into a pandas dataframe.

# %%
df_original = pd.read_csv('analytic_data2019.csv')
df_original.head()
# Out:
#   State FIPS Code County FIPS Code 5-digit FIPS Code State Abbreviation  \
# 0       statecode       countycode          fipscode              state
# 1              00              000             00000                 US
# 2              01              000             01000                 AL
# 3              01              001             01001                 AL
# 4              01              003             01003                 AL
#
#              Name Release Year County Ranked (Yes=1/No=0)  \
# 0          county         year              county_ranked
# 1   United States         2019                        NaN
# 2         Alabama         2019                        NaN
# 3  Autauga County         2019                          1
# 4  Baldwin County         2019                          1
#
#   Premature death raw value Premature death numerator  \
# 0             v001_rawvalue            v001_numerator
# 1               6900.630354                   3745538
# 2              9917.2328984                     80440
# 3              8824.0571232                       815
# 4              7224.6321603                      2827
#
#   Premature death denominator  ... Male population 18-44 raw value  \
# 0            v001_denominator  ...                   v013_rawvalue
# 1                   908266078  ...                             NaN
# 2                    13636816  ...                             NaN
# 3                      156132  ...                             NaN
# 4                      576496  ...                             NaN
#
#   Male population 45-64 raw value Male population 65+ raw value  \
# 0                   v016_rawvalue                 v017_rawvalue
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
#
#   Total male population raw value Female population 0-17 raw value  \
# 0                   v025_rawvalue                    v026_rawvalue
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
#
#   Female population 18-44 raw value Female population 45-64 raw value  \
# 0                     v027_rawvalue                     v031_rawvalue
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   Female population 65+ raw value Total female population raw value  \
# 0                   v032_rawvalue                     v035_rawvalue
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
#
#   Population growth raw value
# 0               v097_rawvalue
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 534 columns]

# %%
print('Number of rows: ', len(df))
print('Number of columns: ', len(df.columns))
# Out:
# Number of rows:  3192
# Number of columns:  534

# %%
missingno.matrix(df_original, figsize=(16,6))
plt.show()

# %%
df_original['Poor mental health days raw value'].isnull().sum()
# Out:
# 1

# %% [markdown]
# # 3. Data Wrangling

# %%
df_cleaning = df_original.copy()

# %%
df_cleaning.drop(df_cleaning.index[[0]], inplace=True)
df_cleaning.head(2)
# Out:
#   State FIPS Code County FIPS Code 5-digit FIPS Code State Abbreviation  \
# 1              00              000             00000                 US
# 2              01              000             01000                 AL
#
#             Name Release Year County Ranked (Yes=1/No=0)  \
# 1  United States         2019                        NaN
# 2        Alabama         2019                        NaN
#
#   Premature death raw value Premature death numerator  \
# 1               6900.630354                   3745538
# 2              9917.2328984                     80440
#
#   Premature death denominator  ... Male population 18-44 raw value  \
# 1                   908266078  ...                             NaN
# 2                    13636816  ...                             NaN
#
#   Male population 45-64 raw value Male population 65+ raw value  \
# 1                             NaN                           NaN
# 2                             NaN                           NaN
#
#   Total male population raw value Female population 0-17 raw value  \
# 1                             NaN                              NaN
# 2                             NaN                              NaN
#
#   Female population 18-44 raw value Female population 45-64 raw value  \
# 1                               NaN                               NaN
# 2                               NaN                               NaN
#
#   Female population 65+ raw value Total female population raw value  \
# 1                             NaN                               NaN
# 2                             NaN                               NaN
#
#   Population growth raw value
# 1                         NaN
# 2                         NaN
#
# [2 rows x 534 columns]

# %%
df_cleaning['County Ranked (Yes=1/No=0)'].fillna(0, inplace=True)

# %%
df_cleaning = df_cleaning[df_cleaning['County Ranked (Yes=1/No=0)'] != 0]

# %%
print('Number of rows: ', len(df_cleaning))
# Out:
# Number of rows:  3095

# %%
df_cleaning.drop(columns=['State FIPS Code','County FIPS Code',
                          '5-digit FIPS Code','Release Year','County Ranked (Yes=1/No=0)'], inplace=True)
df_cleaning.head(2)
# Out:
#   State Abbreviation            Name Premature death raw value  \
# 3                 AL  Autauga County              8824.0571232
# 4                 AL  Baldwin County              7224.6321603
#
#   Premature death numerator Premature death denominator  \
# 3                       815                      156132
# 4                      2827                      576496
#
#   Premature death CI low Premature death CI high Premature death (Black)  \
# 3           7935.3258295            9712.7884169            10471.252986
# 4           6794.1283802            7655.1359403            10042.472874
#
#   Premature death (Hispanic) Premature death (White)  ...  \
# 3                        NaN            8706.6588323  ...
# 4               3086.6056945            7277.7807271  ...
#
#   Male population 18-44 raw value Male population 45-64 raw value  \
# 3                             NaN                             NaN
# 4                             NaN                             NaN
#
#   Male population 65+ raw value Total male population raw value  \
# 3                           NaN                             NaN
# 4                           NaN                             NaN
#
#   Female population 0-17 raw value Female population 18-44 raw value  \
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#   Female population 45-64 raw value Female population 65+ raw value  \
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#   Total female population raw value Population growth raw value
# 3                               NaN                         NaN
# 4                               NaN                         NaN
#
# [2 rows x 529 columns]

# %%
columns = df_cleaning.columns
columns_included = list(filter(lambda column: column != 'State Abbreviation' and column != 'Name', columns))

for column in columns_included:
    df_cleaning[column] = df_cleaning[column].astype(float)

# %%
search_terms = ['White','white','Black','black','Hispanic','hispanic','CI','numerator','denominator']

columns_to_drop = []

for term in search_terms:
    
    df_cleaning_2 = df_cleaning.filter(regex=term)
    columns_to_drop.append(list(df_cleaning_2.columns))

columns_to_drop = list(itertools.chain(*columns_to_drop))
print('Number of columns to drop: ', len(columns_to_drop))
# Out:
# Number of columns to drop:  450

# %%
df_cleaning.drop(columns=columns_to_drop, inplace=True)

# %%
print('Number of columns in dataframe: ', len(df_cleaning.columns))
# Out:
# Number of columns in dataframe:  109

# %%
df_cleaning['Population growth raw value'].isnull().sum()
# Out:
# 3023

# %%
df_cleaning = df_cleaning.loc[:, df_cleaning.isnull().mean() < .8]
print('Number of columns: ', len(df_cleaning.columns))
# Out:
# Number of columns:  76

# %%
df_cleaning.reset_index(drop=True, inplace=True)

# %%
df_cleaning.head(5)
# Out:
#   State Abbreviation            Name  Premature death raw value  \
# 0                 AL  Autauga County                8824.057123
# 1                 AL  Baldwin County                7224.632160
# 2                 AL  Barbour County                9586.165037
# 3                 AL     Bibb County               11783.543675
# 4                 AL   Blount County               10908.101822
#
#    Poor or fair health raw value  Poor physical health days raw value  \
# 0                       0.184111                             4.200578
# 1                       0.180605                             4.098748
# 2                       0.257734                             5.067438
# 3                       0.199969                             4.363377
# 4                       0.210953                             4.512753
#
#    Poor mental health days raw value  Low birthweight raw value  \
# 0                           4.306739                   0.084757
# 1                           4.249649                   0.083387
# 2                           4.634994                   0.109526
# 3                           4.315710                   0.111050
# 4                           4.701599                   0.079268
#
#    Adult smoking raw value  Adult obesity raw value  \
# 0                 0.191247                    0.375
# 1                 0.167955                    0.310
# 2                 0.215409                    0.443
# 3                 0.199164                    0.378
# 4                 0.196522                    0.344
#
#    Food environment index raw value  ...  \
# 0                               7.2  ...
# 1                               8.0  ...
# 2                               5.6  ...
# 3                               7.6  ...
# 4                               8.5  ...
#
#    Severe housing cost burden raw value  Population raw value  \
# 0                              0.126452               55504.0
# 1                              0.127959              212628.0
# 2                              0.135868               25270.0
# 3                              0.087339               22668.0
# 4                              0.081945               58013.0
#
#    % below 18 years of age raw value  % 65 and older raw value  \
# 0                           0.239370                  0.151196
# 1                           0.218485                  0.199470
# 2                           0.207638                  0.188247
# 3                           0.206061                  0.160226
# 4                           0.233499                  0.178426
#
#    % American Indian and Alaskan Native raw value  % Asian raw value  \
# 0                                        0.004756           0.012792
# 1                                        0.007760           0.011565
# 2                                        0.006529           0.004630
# 3                                        0.004279           0.002206
# 4                                        0.006326           0.003017
#
#    % Native Hawaiian/Other Pacific Islander raw value  \
# 0                                           0.001045
# 1                                           0.000687
# 2                                           0.001860
# 3                                           0.001147
# 4                                           0.001172
#
#    % not proficient in English raw value  % Females raw value  \
# 0                               0.008285             0.513422
# 1                               0.004545             0.514528
# 2                               0.011993             0.472299
# 3                               0.003943             0.464531
# 4                               0.018700             0.506886
#
#    % Rural raw value
# 0           0.420022
# 1           0.422791
# 2           0.677896
# 3           0.683526
# 4           0.899515
#
# [5 rows x 76 columns]

# %%
df_cleaning.isnull().sum()
# Out:
# State Abbreviation                                     0
# Name                                                   0
# Premature death raw value                             14
# Poor or fair health raw value                          0
# Poor physical health days raw value                    0
#                                                       ..
# % Asian raw value                                      0
# % Native Hawaiian/Other Pacific Islander raw value     0
# % not proficient in English raw value                  0
# % Females raw value                                    0
# % Rural raw value                                      7
# Length: 76, dtype: int64

# %%
county_names = df_cleaning["Name"]
df_cleaning.drop(columns=["Name"], inplace=True)

# %%
df_cleaning.head(2)
# Out:
#   State Abbreviation  Premature death raw value  \
# 0                 AL                8824.057123
# 1                 AL                7224.632160
#
#    Poor or fair health raw value  Poor physical health days raw value  \
# 0                       0.184111                             4.200578
# 1                       0.180605                             4.098748
#
#    Poor mental health days raw value  Low birthweight raw value  \
# 0                           4.306739                   0.084757
# 1                           4.249649                   0.083387
#
#    Adult smoking raw value  Adult obesity raw value  \
# 0                 0.191247                    0.375
# 1                 0.167955                    0.310
#
#    Food environment index raw value  Physical inactivity raw value  ...  \
# 0                               7.2                          0.311  ...
# 1                               8.0                          0.238  ...
#
#    Severe housing cost burden raw value  Population raw value  \
# 0                              0.126452               55504.0
# 1                              0.127959              212628.0
#
#    % below 18 years of age raw value  % 65 and older raw value  \
# 0                           0.239370                  0.151196
# 1                           0.218485                  0.199470
#
#    % American Indian and Alaskan Native raw value  % Asian raw value  \
# 0                                        0.004756           0.012792
# 1                                        0.007760           0.011565
#
#    % Native Hawaiian/Other Pacific Islander raw value  \
# 0                                           0.001045
# 1                                           0.000687
#
#    % not proficient in English raw value  % Females raw value  \
# 0                               0.008285             0.513422
# 1                               0.004545             0.514528
#
#    % Rural raw value
# 0           0.420022
# 1           0.422791
#
# [2 rows x 75 columns]

# %%
df_cleaning.iloc[:,1:] = df_cleaning.groupby("State Abbreviation").transform(lambda x: x.fillna(x.median()))

# %%
df_cleaning.isnull().sum().sum()
# Out:
# 214

# %%
columns = df_cleaning.columns
columns_with_nulls = []

for column in columns:
    if df_cleaning[column].isnull().sum() > 0:
        columns_with_nulls.append(column)

columns_with_nulls
# Out:
# ['Air pollution - particulate matter raw value',
#  'Drinking water violations raw value',
#  'HIV prevalence raw value',
#  'Children eligible for free or reduced price lunch raw value']

# %%
df_cleaning.drop(columns=columns_with_nulls, inplace=True)

# %%
df_cleaning.insert(1, "County Name", county_names)

# %%
poor_mental_health = df_cleaning['Poor mental health days raw value']
df_cleaning.drop(columns=['Poor mental health days raw value'], inplace=True)
df_cleaning.insert(2, "Poor mental health days", poor_mental_health)

# %%
df_cleaning.head()
# Out:
#   State Abbreviation     County Name  Poor mental health days  \
# 0                 AL  Autauga County                 4.306739
# 1                 AL  Baldwin County                 4.249649
# 2                 AL  Barbour County                 4.634994
# 3                 AL     Bibb County                 4.315710
# 4                 AL   Blount County                 4.701599
#
#    Premature death raw value  Poor or fair health raw value  \
# 0                8824.057123                       0.184111
# 1                7224.632160                       0.180605
# 2                9586.165037                       0.257734
# 3               11783.543675                       0.199969
# 4               10908.101822                       0.210953
#
#    Poor physical health days raw value  Low birthweight raw value  \
# 0                             4.200578                   0.084757
# 1                             4.098748                   0.083387
# 2                             5.067438                   0.109526
# 3                             4.363377                   0.111050
# 4                             4.512753                   0.079268
#
#    Adult smoking raw value  Adult obesity raw value  \
# 0                 0.191247                    0.375
# 1                 0.167955                    0.310
# 2                 0.215409                    0.443
# 3                 0.199164                    0.378
# 4                 0.196522                    0.344
#
#    Food environment index raw value  ...  \
# 0                               7.2  ...
# 1                               8.0  ...
# 2                               5.6  ...
# 3                               7.6  ...
# 4                               8.5  ...
#
#    Severe housing cost burden raw value  Population raw value  \
# 0                              0.126452               55504.0
# 1                              0.127959              212628.0
# 2                              0.135868               25270.0
# 3                              0.087339               22668.0
# 4                              0.081945               58013.0
#
#    % below 18 years of age raw value  % 65 and older raw value  \
# 0                           0.239370                  0.151196
# 1                           0.218485                  0.199470
# 2                           0.207638                  0.188247
# 3                           0.206061                  0.160226
# 4                           0.233499                  0.178426
#
#    % American Indian and Alaskan Native raw value  % Asian raw value  \
# 0                                        0.004756           0.012792
# 1                                        0.007760           0.011565
# 2                                        0.006529           0.004630
# 3                                        0.004279           0.002206
# 4                                        0.006326           0.003017
#
#    % Native Hawaiian/Other Pacific Islander raw value  \
# 0                                           0.001045
# 1                                           0.000687
# 2                                           0.001860
# 3                                           0.001147
# 4                                           0.001172
#
#    % not proficient in English raw value  % Females raw value  \
# 0                               0.008285             0.513422
# 1                               0.004545             0.514528
# 2                               0.011993             0.472299
# 3                               0.003943             0.464531
# 4                               0.018700             0.506886
#
#    % Rural raw value
# 0           0.420022
# 1           0.422791
# 2           0.677896
# 3           0.683526
# 4           0.899515
#
# [5 rows x 72 columns]

# %%
df_cleaning_1 = df_cleaning.copy()

# %%
df_cleaning_1.drop(columns=["State Abbreviation","County Name"], inplace=True)

# %%
corr_mat_1 = df_cleaning_1.corr()

# %%
plt.figure(figsize=(14,14))

ax = sns.heatmap(corr_mat_1)

# %% [markdown]
# From the correlation matrix it is clear that life expectancy is strongly negatively correlated with many of the other values. This colinearity should be avoided. It is also likely that the dependant variable of this study, poor mental health, may be a causal factor in shorter life expectancy, not the other way around. For these reasons, this column is dropped from the study. Frequent mental distress and poor mental health days are proxies of each other and therefore the frequent mental distress variable was also dropped.

# %%
df_cleaning_1.drop(columns=["Life expectancy raw value","Frequent mental distress raw value"], inplace=True)

# %%
corr_mat_2 = df_cleaning_1.corr()

# %%
corr_mat_2['Poor mental health days'].abs().sort_values(ascending=False)[1:11]
# Out:
# Poor physical health days raw value           0.918735
# Frequent physical distress raw value          0.877342
# Poor or fair health raw value                 0.741214
# Adult smoking raw value                       0.739944
# Insufficient sleep raw value                  0.684812
# Diabetes prevalence raw value                 0.655727
# Premature age-adjusted mortality raw value    0.648104
# Children in poverty raw value                 0.643349
# Excessive drinking raw value                  0.621617
# Food insecurity raw value                     0.609024
# Name: Poor mental health days, dtype: float64

# %% [markdown]
# # 4. Modelling

# %%
df_modelling_1 = df_cleaning.copy()

# %%
fig, ax = plt.subplots(figsize=(16,12))

sns.regplot(x='Frequent physical distress raw value', 
            y='Poor mental health days',
            data=df_modelling_1,
            color='blue',
            scatter_kws={'alpha':0.3},
            label='Physical distress',
            ax=ax)
sns.regplot(x='Adult smoking raw value', 
            y='Poor mental health days',
            data=df_modelling_1,
            color='red',
            scatter_kws={'alpha':0.3},
            label='Adult smoking',
            ax=ax)
sns.regplot(x='Insufficient sleep raw value', 
            y='Poor mental health days',
            data=df_modelling_1,
            color='green',
            scatter_kws={'alpha':0.3},
            label='Insufficient sleep',
            ax=ax)
plt.legend(fontsize=14)
plt.xlabel('Percentage', fontsize=14)
plt.ylabel('Number of Poor Mental Health Days per Month', fontsize=14)
plt.show()

# %%
sns.lmplot(x='Frequent physical distress raw value', y='Poor mental health days', 
           data=df_modelling_1, height=11, aspect=1)
sns.lmplot(x='Adult smoking raw value', y='Poor mental health days', 
           data=df_modelling_1, height=11, aspect=1)
plt.show()

# %% [markdown]
# # 5. Evaluation
